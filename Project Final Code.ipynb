# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Basic Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# warnings removal
import warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,roc_auc_score
from sklearn.feature_selection import RFE,SelectKBest,SelectFromModel
from sklearn.model_selection import GridSearchCV,cross_val_score,StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Load dataset
data = pd.read_csv("/content/drive/MyDrive/8th Semester/Artificial Intelligence/Lab/DATA SET/Final_Blood_samples_dataset.csv")

# %%
data.head()
# Out:
#     Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0  0.739597     0.650198    0.713631   0.868491           0.687433
# 1  0.121786     0.023058    0.944893   0.905372           0.507711
# 2  0.452539     0.116135    0.544560   0.400640           0.294538
# 3  0.136609     0.015605    0.419957   0.191487           0.081168
# 4  0.176737     0.752220    0.971779   0.785286           0.443880
#
#    Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0         0.529895    0.290006                 0.631045
# 1         0.403033    0.164216                 0.307553
# 2         0.382021    0.625267                 0.295122
# 3         0.166214    0.073293                 0.668719
# 4         0.439851    0.894991                 0.442159
#
#    Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                     0.001328                                   0.795829
# 1                     0.207938                                   0.505562
# 2                     0.868369                                   0.026808
# 3                     0.125447                                   0.501051
# 4                     0.257288                                   0.805987
#
#    ...     HbA1c  LDL Cholesterol  HDL Cholesterol       ALT       AST  \
# 0  ...  0.502665         0.215560         0.512941  0.064187  0.610827
# 1  ...  0.856810         0.652465         0.106961  0.942549  0.344261
# 2  ...  0.466795         0.387332         0.421763  0.007186  0.506918
# 3  ...  0.016256         0.040137         0.826721  0.265415  0.594148
# 4  ...  0.429431         0.146294         0.221574  0.015280  0.567115
#
#    Heart Rate  Creatinine  Troponin  C-reactive Protein   Disease
# 0    0.939485    0.095512  0.465957            0.769230   Healthy
# 1    0.666368    0.659060  0.816982            0.401166  Diabetes
# 2    0.431704    0.417295  0.799074            0.779208  Thalasse
# 3    0.225756    0.490349  0.637061            0.354094    Anemia
# 4    0.841412    0.153350  0.794008            0.094970  Thalasse
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (2837, 25)

# %%
# Let's find out how many of each class there
data.Disease.value_counts()
# Out:
# Disease
# Diabetes    834
# Anemia      707
# Healthy     561
# Thalasse    557
# Thromboc    139
# Heart Di     39
# Name: count, dtype: int64

# %%
# Let's convert our target column to numeric values.
data.Disease = data.Disease.astype('category')
d = dict(enumerate(data['Disease'].cat.categories))
data.Disease = data.Disease.cat.codes.values
data.Disease
# Out:
# 0       2
# 1       1
# 2       4
# 3       0
# 4       4
#        ..
# 2832    1
# 2833    3
# 2834    0
# 2835    1
# 2836    1
# Name: Disease, Length: 2837, dtype: int8

# %%
# Make a correlation matrix
plt.figure(figsize=(20, 10))
heatmap = sns.heatmap(data.corr(), vmin=-1, vmax=1, annot=True,cmap='BrBG')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':14}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Let's find how many of each class there are in the bar chart.
counts = data[data.columns[-1]].value_counts()
palette = sns.color_palette()
fig, axes = plt.subplots(figsize=(10,6))
counts.plot(kind="bar", ax=axes, color=palette)
plt.xlabel('Diseases',labelpad=10)
for container in axes.containers:
    axes.bar_label(container)
plt.show()

# %%
fig, axs = plt.subplots(nrows=5, ncols=5, figsize=(15, 15))

# Draw a distplot for each column and add it to the subplot
for i, col in enumerate(data.columns):
    sns.distplot(data[col], ax=axs[i//5, i%5])
    axs[i//5, i%5].set_title(col)

# Hide missing subplots
for i in range(len(data.columns), 25):
    axs[i//5, i%5].axis('off')

#  Show charts
plt.tight_layout()
plt.show()

# %%
# Draw a boxplot for each column
index = 0
for i in range(0, len(data.columns) - 1, 4):
    fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16, 4))
    for j, ax in enumerate(axes.flat):
        if index < len(data.columns) - 1:
            sns.boxplot(data=data, x=data.columns[-1], y=data.columns[index], ax=ax)
            ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
            index += 1
    plt.tight_layout()
    plt.show()

# %%
data['Hemoglobin'].describe()
# Out:
# count    2837.000000
# mean        0.568941
# std         0.278908
# min         0.000719
# 25%         0.325035
# 50%         0.597916
# 75%         0.791215
# max         0.997876
# Name: Hemoglobin, dtype: float64

# %%
X = data.drop('Disease',axis=1)
y = data['Disease']

# %%
X
# Out:
#        Glucose  Cholesterol  Hemoglobin  Platelets  White Blood Cells  \
# 0     0.739597     0.650198    0.713631   0.868491           0.687433
# 1     0.121786     0.023058    0.944893   0.905372           0.507711
# 2     0.452539     0.116135    0.544560   0.400640           0.294538
# 3     0.136609     0.015605    0.419957   0.191487           0.081168
# 4     0.176737     0.752220    0.971779   0.785286           0.443880
# ...        ...          ...         ...        ...                ...
# 2832  0.985163     0.412960    0.529993   0.263765           0.431288
# 2833  0.581914     0.629325    0.491644   0.901473           0.347797
# 2834  0.066669     0.404558    0.591041   0.228401           0.127461
# 2835  0.901444     0.430680    0.243853   0.825551           0.493884
# 2836  0.877912     0.597809    0.730440   0.462307           0.498438
#
#       Red Blood Cells  Hematocrit  Mean Corpuscular Volume  \
# 0            0.529895    0.290006                 0.631045
# 1            0.403033    0.164216                 0.307553
# 2            0.382021    0.625267                 0.295122
# 3            0.166214    0.073293                 0.668719
# 4            0.439851    0.894991                 0.442159
# ...               ...         ...                      ...
# 2832         0.198882    0.581289                 0.701192
# 2833         0.633286    0.698114                 0.516947
# 2834         0.026670    0.847444                 0.279740
# 2835         0.726299    0.660930                 0.445560
# 2836         0.792822    0.976056                 0.883937
#
#       Mean Corpuscular Hemoglobin  Mean Corpuscular Hemoglobin Concentration  \
# 0                        0.001328                                   0.795829
# 1                        0.207938                                   0.505562
# 2                        0.868369                                   0.026808
# 3                        0.125447                                   0.501051
# 4                        0.257288                                   0.805987
# ...                           ...                                        ...
# 2832                     0.249410                                   0.246893
# 2833                     0.674259                                   0.798153
# 2834                     0.575425                                   0.156438
# 2835                     0.349782                                   0.343069
# 2836                     0.202147                                   0.930649
#
#       ...  Triglycerides     HbA1c  LDL Cholesterol  HDL Cholesterol  \
# 0     ...       0.653472  0.502665         0.215560         0.512941
# 1     ...       0.477742  0.856810         0.652465         0.106961
# 2     ...       0.088940  0.466795         0.387332         0.421763
# 3     ...       0.406528  0.016256         0.040137         0.826721
# 4     ...       0.414407  0.429431         0.146294         0.221574
# ...   ...            ...       ...              ...              ...
# 2832  ...       0.763585  0.680556         0.048191         0.465272
# 2833  ...       0.797147  0.261767         0.482322         0.799523
# 2834  ...       0.034523  0.168146         0.763625         0.677782
# 2835  ...       0.366494  0.893448         0.500059         0.112250
# 2836  ...       0.673507  0.242163         0.783372         0.568568
#
#            ALT       AST  Heart Rate  Creatinine  Troponin  C-reactive Protein
# 0     0.064187  0.610827    0.939485    0.095512  0.465957            0.769230
# 1     0.942549  0.344261    0.666368    0.659060  0.816982            0.401166
# 2     0.007186  0.506918    0.431704    0.417295  0.799074            0.779208
# 3     0.265415  0.594148    0.225756    0.490349  0.637061            0.354094
# 4     0.015280  0.567115    0.841412    0.153350  0.794008            0.094970
# ...        ...       ...         ...         ...       ...                 ...
# 2832  0.066511  0.965544    0.015051    0.442730  0.196986            0.816038
# 2833  0.807460  0.325313    0.825194    0.777866  0.415987            0.842804
# 2834  0.890501  0.638825    0.559993    0.795478  0.669925            0.124874
# 2835  0.548469  0.211496    0.938355    0.463381  0.862921            0.658526
# 2836  0.784730  0.500928    0.016738    0.104687  0.055181            0.049341
#
# [2837 rows x 24 columns]

# %%
y
# Out:
# 0       2
# 1       1
# 2       4
# 3       0
# 4       4
#        ..
# 2832    1
# 2833    3
# 2834    0
# 2835    1
# 2836    1
# Name: Disease, Length: 2837, dtype: int8

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=10,stratify= y)

# %%
results = pd.DataFrame([],columns=['Accuracy','train Accuracy'])

# %%
print('train shape:',X_train.shape)
print('test shape: ',X_test.shape)
# Out:
# train shape: (2269, 24)
# test shape:  (568, 24)

# %%
# standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# create ann model
ann = tf.keras.models.Sequential()
ann.add(tf.keras.layers.Dense(256, activation='relu', input_shape=(X_train_scaled.shape[1],)))
ann.add(tf.keras.layers.Dropout(0.2))
ann.add(tf.keras.layers.Dense(128, activation='relu'))
ann.add(tf.keras.layers.Dropout(0.2))
ann.add(tf.keras.layers.Dense(64,activation='relu'))
ann.add(tf.keras.layers.Dropout(0.2))
ann.add( tf.keras.layers.Dense(6, activation='softmax'))

# %%
# let's compile our model.
ann.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
# Let's add an early stop command.
early_stopping = tf.keras.callbacks.EarlyStopping(patience=30, restore_best_weights=True, monitor='val_loss')

# %%
# model fit
history = ann.fit(X_train_scaled, y_train, epochs=100,
                    validation_split=0.1, callbacks=[early_stopping], verbose=2)
# Out:
# Epoch 1/100
# 64/64 - 4s - 58ms/step - accuracy: 0.5651 - loss: 1.1428 - val_accuracy: 0.9031 - val_loss: 0.4890
# Epoch 2/100
# 64/64 - 1s - 9ms/step - accuracy: 0.8830 - loss: 0.4567 - val_accuracy: 0.9383 - val_loss: 0.2268
# Epoch 3/100
# 64/64 - 1s - 9ms/step - accuracy: 0.9261 - loss: 0.2933 - val_accuracy: 0.9471 - val_loss: 0.1880
# Epoch 4/100
# 64/64 - 1s - 14ms/step - accuracy: 0.9314 - loss: 0.2361 - val_accuracy: 0.9427 - val_loss: 0.1980
# Epoch 5/100
# 64/64 - 1s - 8ms/step - accuracy: 0.9491 - loss: 0.1740 - val_accuracy: 0.9471 - val_loss: 0.1653
# Epoch 6/100
# 64/64 - 1s - 9ms/step - accuracy: 0.9525 - loss: 0.1506 - val_accuracy: 0.9471 - val_loss: 0.1653
# Epoch 7/100
# 64/64 - 1s - 12ms/step - accuracy: 0.9613 - loss: 0.1265 - val_accuracy: 0.9471 - val_loss: 0.1817
# Epoch 8/100
# 64/64 - 1s - 12ms/step - accuracy: 0.9574 - loss: 0.1212 - val_accuracy: 0.9427 - val_loss: 0.1797
# Epoch 9/100
# 64/64 - 1s - 12ms/step - accuracy: 0.9716 - loss: 0.0983 - val_accuracy: 0.9427 - val_loss: 0.1848
# Epoch 10/100
# 64/64 - 1s - 13ms/step - accuracy: 0.9706 - loss: 0.0852 - val_accuracy: 0.9515 - val_loss: 0.1554
# Epoch 11/100
# 64/64 - 1s - 18ms/step - accuracy: 0.9775 - loss: 0.0706 - val_accuracy: 0.9471 - val_loss: 0.1672
# Epoch 12/100
# 64/64 - 1s - 13ms/step - accuracy: 0.9789 - loss: 0.0607 - val_accuracy: 0.9515 - val_loss: 0.1628
# Epoch 13/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9838 - loss: 0.0566 - val_accuracy: 0.9515 - val_loss: 0.1567
# Epoch 14/100
# 64/64 - 0s - 4ms/step - accuracy: 0.9785 - loss: 0.0530 - val_accuracy: 0.9515 - val_loss: 0.1756
# Epoch 15/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9873 - loss: 0.0418 - val_accuracy: 0.9515 - val_loss: 0.1477
# Epoch 16/100
# 64/64 - 1s - 9ms/step - accuracy: 0.9853 - loss: 0.0451 - val_accuracy: 0.9427 - val_loss: 0.1710
# Epoch 17/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9882 - loss: 0.0390 - val_accuracy: 0.9515 - val_loss: 0.1587
# Epoch 18/100
# 64/64 - 0s - 4ms/step - accuracy: 0.9863 - loss: 0.0387 - val_accuracy: 0.9559 - val_loss: 0.1660
# Epoch 19/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9902 - loss: 0.0323 - val_accuracy: 0.9604 - val_loss: 0.1460
# Epoch 20/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9902 - loss: 0.0297 - val_accuracy: 0.9604 - val_loss: 0.1462
# Epoch 21/100
# 64/64 - 1s - 9ms/step - accuracy: 0.9931 - loss: 0.0227 - val_accuracy: 0.9559 - val_loss: 0.1728
# Epoch 22/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9917 - loss: 0.0248 - val_accuracy: 0.9604 - val_loss: 0.1587
# Epoch 23/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9902 - loss: 0.0328 - val_accuracy: 0.9471 - val_loss: 0.1803
# Epoch 24/100
# 64/64 - 1s - 9ms/step - accuracy: 0.9961 - loss: 0.0159 - val_accuracy: 0.9604 - val_loss: 0.1737
# Epoch 25/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9956 - loss: 0.0161 - val_accuracy: 0.9427 - val_loss: 0.1959
# Epoch 26/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9976 - loss: 0.0116 - val_accuracy: 0.9471 - val_loss: 0.1922
# Epoch 27/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9956 - loss: 0.0160 - val_accuracy: 0.9515 - val_loss: 0.1921
# Epoch 28/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9971 - loss: 0.0114 - val_accuracy: 0.9515 - val_loss: 0.2211
# Epoch 29/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9897 - loss: 0.0286 - val_accuracy: 0.9471 - val_loss: 0.1929
# Epoch 30/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9922 - loss: 0.0229 - val_accuracy: 0.9604 - val_loss: 0.1708
# Epoch 31/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9951 - loss: 0.0137 - val_accuracy: 0.9515 - val_loss: 0.2008
# Epoch 32/100
# 64/64 - 1s - 10ms/step - accuracy: 0.9976 - loss: 0.0147 - val_accuracy: 0.9515 - val_loss: 0.1882
# Epoch 33/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9956 - loss: 0.0139 - val_accuracy: 0.9515 - val_loss: 0.2005
# Epoch 34/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9946 - loss: 0.0120 - val_accuracy: 0.9559 - val_loss: 0.2232
# Epoch 35/100
# 64/64 - 0s - 4ms/step - accuracy: 0.9956 - loss: 0.0124 - val_accuracy: 0.9471 - val_loss: 0.1706
# Epoch 36/100
# 64/64 - 0s - 4ms/step - accuracy: 0.9971 - loss: 0.0126 - val_accuracy: 0.9515 - val_loss: 0.2406
# Epoch 37/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9922 - loss: 0.0232 - val_accuracy: 0.9604 - val_loss: 0.1911
# Epoch 38/100
# 64/64 - 0s - 4ms/step - accuracy: 0.9980 - loss: 0.0123 - val_accuracy: 0.9604 - val_loss: 0.1857
# Epoch 39/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9951 - loss: 0.0164 - val_accuracy: 0.9515 - val_loss: 0.2391
# Epoch 40/100
# 64/64 - 0s - 7ms/step - accuracy: 0.9961 - loss: 0.0151 - val_accuracy: 0.9604 - val_loss: 0.2017
# Epoch 41/100
# 64/64 - 1s - 10ms/step - accuracy: 0.9956 - loss: 0.0164 - val_accuracy: 0.9515 - val_loss: 0.2364
# Epoch 42/100
# 64/64 - 1s - 10ms/step - accuracy: 0.9971 - loss: 0.0085 - val_accuracy: 0.9515 - val_loss: 0.2429
# Epoch 43/100
# 64/64 - 1s - 9ms/step - accuracy: 0.9976 - loss: 0.0097 - val_accuracy: 0.9515 - val_loss: 0.2528
# Epoch 44/100
# 64/64 - 1s - 10ms/step - accuracy: 0.9966 - loss: 0.0142 - val_accuracy: 0.9559 - val_loss: 0.2459
# Epoch 45/100
# 64/64 - 0s - 7ms/step - accuracy: 0.9966 - loss: 0.0113 - val_accuracy: 0.9515 - val_loss: 0.2723
# Epoch 46/100
# 64/64 - 1s - 10ms/step - accuracy: 0.9976 - loss: 0.0097 - val_accuracy: 0.9515 - val_loss: 0.2826
# Epoch 47/100
# 64/64 - 1s - 9ms/step - accuracy: 0.9980 - loss: 0.0097 - val_accuracy: 0.9559 - val_loss: 0.2590
# Epoch 48/100
# 64/64 - 0s - 4ms/step - accuracy: 0.9990 - loss: 0.0059 - val_accuracy: 0.9604 - val_loss: 0.2423
# Epoch 49/100
# 64/64 - 0s - 5ms/step - accuracy: 0.9961 - loss: 0.0109 - val_accuracy: 0.9515 - val_loss: 0.2865

# %%
print('test set',ann.evaluate(X_test_scaled,y_test)) # test set result
print('train set',ann.evaluate(X_train_scaled,y_train)) # train set result
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9241 - loss: 0.3355
# test set [0.32020172476768494, 0.9207746386528015]
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0075
# train set [0.019128132611513138, 0.9955927729606628]

# %%
ann_acc = ann.evaluate(X_test_scaled,y_test)
train_accuracy = ann.evaluate(X_train_scaled,y_train)
results.loc['ANN Model'] = [ann_acc,train_accuracy]
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9241 - loss: 0.3355
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9985 - loss: 0.0075

# %%
#  Let's plot the training set and validation set losses on a graph.
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['loss','val_loss'])

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['accuracy','val_accuracy'],loc='best')

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# All score DataFrame
results = pd.DataFrame([],columns=['Accuracy Score','Train Accuracy'])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, confusion_matrix,ConfusionMatrixDisplay

# %%
# Standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Create model
model = GradientBoostingClassifier(ccp_alpha=0.001, learning_rate=0.01,
                            n_estimators=500, random_state=10)
# Model fit
model.fit(X_train_scaled,y_train)
# model predict
y_pred = model.predict(X_test_scaled)
acc= accuracy_score(y_test,y_pred)

print('GradientBoostingClassifier accuracy is:',acc)
# Out:
# GradientBoostingClassifier accuracy is: 0.9577464788732394

# %%
# train set predict
y_train_pred = model.predict(X_train_scaled)
train_acc = accuracy_score(y_train,y_train_pred)
print('train set accuracy is:',train_acc)


results.loc['GradientBoostingClassifier'] = [acc,train_acc]
# Out:
# train set accuracy is: 0.9731159100925518

# %%
# !pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from pydotplus) (3.2.3)

# %%
from sklearn.tree import export_graphviz
from pydotplus import graph_from_dot_data
from IPython.display import Image

sub_tree_42 = model.estimators_[42,0]

dot_data = export_graphviz(
    sub_tree_42,
    rotate = True,
    out_file=None, filled=True, rounded=True,
    special_characters=True,
    proportion=True, impurity=True, # enable them if you want
)
graph = graph_from_dot_data(dot_data)
png = graph.create_png()
# Display
Image(png)

# %%
# auc score of the multiclass model.
y_proba =np.array(model.predict_proba(X_test_scaled))
score = roc_auc_score(y_test,y_proba,multi_class='ovr',average='macro')
print('auc score of the multiclass model is:',score)
# Out:
# auc score of the multiclass model is: 0.99580599897078

# %%
# confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test,y_pred),
                              display_labels=model.classes_)
disp.plot(cmap='plasma')

plt.show()

# %%
mdl = DecisionTreeClassifier()

path= mdl.cost_complexity_pruning_path(X_train,y_train)
path['ccp_alphas']
# Out:
# array([0.        , 0.00044072, 0.00044072, 0.00044072, 0.00058763,
#        0.00058763, 0.00058763, 0.00077126, 0.00078351, 0.0007933 ,
#        0.0007933 , 0.0008539 , 0.00085474, 0.00086588, 0.00086898,
#        0.00087313, 0.00087537, 0.00087581, 0.00087726, 0.00088145,
#        0.00100567, 0.00105773, 0.00106234, 0.00107977, 0.00110181,
#        0.00113329, 0.00120791, 0.00125436, 0.00125606, 0.00125921,
#        0.00131167, 0.00141091, 0.00151105, 0.00164537, 0.00173851,
#        0.00195244, 0.00196798, 0.00201187, 0.00210224, 0.00247818,
#        0.00255512, 0.00259468, 0.00261621, 0.00305877, 0.00361549,
#        0.00453789, 0.00474187, 0.00504565, 0.00589325, 0.00630737,
#        0.00705207, 0.00722858, 0.00794026, 0.01063061, 0.01141317,
#        0.01161575, 0.01279897, 0.01663738, 0.01690359, 0.01738795,
#        0.01774828, 0.02231182, 0.02241917, 0.02731697, 0.03154103,
#        0.03405757, 0.03817191, 0.05442068, 0.05642132, 0.06872152])

# %%
# standardization
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# create model
mdl = DecisionTreeClassifier(random_state=2,max_features=18,ccp_alpha=0.002478180717510433)
# model fit
mdl.fit(X_train_scaled,y_train)
# test set predict
y_pred = mdl.predict(X_test_scaled)
# train set predict
y_tpred = mdl.predict(X_train_scaled)

train_score = accuracy_score(y_train,y_tpred)
score = accuracy_score(y_test,y_pred)
print('DecisionTreeClassifier accuracy is:',score)
print('DecisionTreeClassifier train accuracy is:',train_score)

results.loc['DecisionTreeClassifier'] = [score,train_score]
# Out:
# DecisionTreeClassifier accuracy is: 0.9383802816901409
# DecisionTreeClassifier train accuracy is: 0.9673865138827678

# %%
from sklearn import tree

# %%
# plot tree
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(mdl,filled=True)

# %%
from xgboost import XGBClassifier

# %%
# standardization
scaler = StandardScaler()
X_train_reduced = scaler.fit_transform(X_train)
X_test_reduced = scaler.transform(X_test)
# create model
boost = XGBClassifier(n_estimators=1000, max_depth=9, learning_rate=0.01,
                       subsample=1,objective='multi:softprob')
# model fit
boost.fit(X_train_reduced,y_train)
# test set predict
y_pred = boost.predict(X_test_reduced)
# train set predict
train_pred = boost.predict(X_train_reduced)

xgb_train = accuracy_score(y_train,train_pred)
xgb_acc = accuracy_score(y_test,y_pred)

results.loc['XGBOOXGBClassifier'] = [xgb_acc,xgb_train]

print('XGBOOXGBClassifier accuracy is:',xgb_acc)
# Out:
# XGBOOXGBClassifier accuracy is: 0.9876760563380281

# %%
from xgboost import plot_tree

# %%
plt.figure(figsize=(20,15))
plot_tree(boost)
plt.show()

# %%
# standardization
scaler = StandardScaler()
X_train_reduced = scaler.fit_transform(X_train)
X_test_reduced = scaler.transform(X_test)

# Create model
logmodel = LogisticRegression(max_iter= 1000, solver = 'saga', penalty= 'l1',
                              random_state = 10, C = 1.0, multi_class = 'multinomial')
# model fit
logmodel.fit(X_train_reduced,y_train)
# test set predict
y_pred = logmodel.predict(X_test_reduced)
# train set predict
train_pred = logmodel.predict(X_train_reduced)

logmodel_train = accuracy_score(y_train,train_pred)
logmodel_acc = accuracy_score(y_test,y_pred)

results.loc['LogisticRegression'] = [logmodel_acc,logmodel_train]

print('LogisticRegression accuracy is:',logmodel_acc)
# Out:
# LogisticRegression accuracy is: 0.8785211267605634

# %%
results
# Out:
#                             Accuracy Score  Train Accuracy
# GradientBoostingClassifier        0.957746        0.973116
# DecisionTreeClassifier            0.938380        0.967387
# XGBOOXGBClassifier                0.987676        1.000000
# LogisticRegression                0.878521        0.878801

# %%
# Accuracy Score
from matplotlib import pyplot as plt
results['Accuracy Score'].plot(kind='line', figsize=(8, 4), title='Accuracy Score')
plt.gca().spines[['top', 'right']].set_visible(False)
